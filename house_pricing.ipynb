# %%
pwd
# Out:
# 'C:\\Users\\Lenovo'

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("House_Price.csv " , header = 0)
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.shape
# Out:
# (506, 19)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x='n_hot_rooms',y = 'price',data = df)
sns.jointplot(x = 'rainfall', y='price', data = df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.countplot(x='airport', data = df)
sns.countplot(x='waterbody', data = df)
# Out:
# <AxesSubplot:xlabel='waterbody', ylabel='count'>

# %%
# OUTLIER TREATMENT
ul = np.percentile(df.n_hot_rooms,[99])[0]
df[(df.n_hot_rooms>ul)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
#CAPPING
df.n_hot_rooms[(df.n_hot_rooms > 2*ul)] = 2*ul
# Out:
# <ipython-input-10-536d516a63e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.n_hot_rooms[(df.n_hot_rooms > 2*ul)] = 2*ul

# %%
df[(df.n_hot_rooms>ul)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394     30.79904
# 166   2.31   1.86      25.3       3.70     YES       8.300     15.40000
# 204   5.28   4.99      25.3       2.88     YES       8.900     15.40000
# 267   2.43   2.52      27.0       7.44     YES       8.000     15.40000
# 369   1.65   0.94      19.8       3.73     YES       6.700     15.40000
# ...

# %%
#same for rainfall
np.percentile(df.rainfall,[1])[0]
# Out:
# 20.0

# %%
lv = np.percentile(df.rainfall,[1])[0]

# %%
df[(df.rainfall < lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
df.rainfall[(df.rainfall <0.6*lv)] = 0.6*lv
# Out:
# <ipython-input-15-a7aad3fa9822>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rainfall[(df.rainfall <0.6*lv)] = 0.6*lv

# %%
sns.jointplot(x='crime_rate', y='price' , data=df)

# %%
# MISSING VALUE IMPUTATION
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.n_hos_beds = df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
#for all columns
df = df.fillna(df.mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
# VARIABLE TRANSFORMATION AND DELETE IN PYTHON
sns.jointplot(x='crime_rate', y='price', data=df)

# %%
df.crime_rate = np.log(1+df.crime_rate)

# %%
sns.jointplot(x='crime_rate', y='price', data=df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480     11.19200
# 1   5.12   5.06      22.2       9.14      NO       7.332     12.17280
# 2   5.01   4.97      22.2       4.03      NO       7.394     30.79904
# 3   6.16   5.96      21.3       2.94     YES       9.268     11.26720
# 4   6.37   5.86      21.3       5.33      NO       8.824     11.28960
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df['avg_dist'] = (df.dist1 + df.dist2 + df.dist3 + df.dist4)/4
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
del df['dist1']
del df['dist2']
del df['dist3']
del df['dist4']
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.803182   39.199605
# ...

# %%
df.crime_rate.unique()
# Out:
# array([0.00630011, 0.02694374, 0.02692427, 0.03185713, 0.0667704 ,
#        0.02941316, 0.08460766, 0.13501155, 0.19164463, 0.15703794,
#        0.20285104, 0.1110672 , 0.08963959, 0.48843276, 0.49345157,
#        0.4869775 , 0.71975503, 0.57897014, 0.58929109, 0.54569071,
#        0.81172546, 0.61628773, 0.8031086 , 0.68734538, 0.55976435,
#        0.61005901, 0.51396669, 0.67078398, 0.57266739, 0.69437143,
#        0.75650219, 0.85642182, 0.87045201, 0.76626752, 0.9604301 ,
#        0.06219515, 0.09298019, 0.07709066, 0.1613107 , 0.02725518,
#        0.03303818, 0.11994958, 0.13234319, 0.14786813, 0.11572759,
#        0.15821669, 0.17257421, 0.2064205 , 0.22623477, 0.19866232,
#        0.08501188, 0.04245586, 0.05221287, 0.0486092 , 0.01350835,
#        0.01302481, 0.0203417 , 0.01421844, 0.14362404, 0.09828756,
#        0.13917046, 0.15846422, 0.10460323, 0.11911548, 0.01932212,
#        0.03521269, 0.04285832, 0.05627636, 0.12710831, 0.12058799,
# ...

# %%
#dummy variables
df = pd.get_dummies(df)
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     30.79904        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del df['airport_NO']
del df['waterbody_None']
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.544466   12.653063    7.899767    12.803182   39.199605
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017596    0.067974   -0.011354  0.013043
# rainfall                 -0.046731    0.081705    0.055898  0.091628
# parks                    -0.391574    0.638951    0.707635  0.915544
# avg_dist                  0.249289   -0.586371   -0.708022 -0.769247
# ...

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     30.79904        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River  \
# ...

# %%
# LINEAR REGRESSION
import statsmodels.api as sn
x = sn.add_constant(df['room_num'])
lm = sn.OLS(df['price'],x).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Sun, 21 Nov 2021   Prob (F-statistic):           1.31e-74
# Time:                        09:58:03   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %%
# SKLEARN
from sklearn.linear_model import LinearRegression

# %%
y=df['price']
x= df[['room_num']]
lm2= LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# -34.65924312309721 [9.09966966]

# %%
lm2.predict(x)
# Out:
# array([25.17108491, 23.76973578, 30.72188341, 29.02024518, 30.37609596,
#        23.85163281, 20.04797089, 21.50391804, 16.58099675, 19.97517353,
#        23.36935032, 20.02067188, 18.92871152, 19.4746917 , 20.81234314,
#        18.42822969, 19.34729633, 19.84777816, 14.98855456, 17.45456504,
#        16.0259169 , 19.62028642, 21.23092795, 18.23713663, 19.24719996,
#        16.28980732, 18.23713663, 20.36645933, 24.44311134, 26.07195221,
#        17.32716966, 20.59395107, 19.48379137, 17.21797363, 20.81234314,
#        19.32909699, 18.49192738, 18.57382441, 19.62938609, 25.3530783 ,
#        29.25683659, 26.9455205 , 21.47661903, 21.85880515, 20.56665206,
#        17.0450799 , 17.99144555, 20.21176495, 14.46987339, 16.31710633,
#        19.60208708, 20.98523687, 24.58870605, 19.92057552, 18.91961185,
#        31.30426226, 23.42394834, 27.3641053 , 21.25822696, 19.27449897,
#        17.58196041, 19.62938609, 24.08822422, 26.87272314, 29.98481016,
# ...

# %%
sns.jointplot(x=df['room_num'],y=df['price'],kind='reg')

# %%
x_multi=df.drop("price" , axis=1)
x_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  airport_YES  \
# 0       5.480     11.19200        23  0.049347    4.0875            1
# 1       7.332     12.17280        42  0.046146    4.9675            0
# 2       7.394     30.79904        38  0.045764    4.9675            0
# 3       9.268     11.26720        45  0.047151    6.0650            1
# 4       8.824     11.28960        55  0.039474    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River  bus_ter_YES
# ...

# %%
y_multi = df['price']
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %%
x_multi_constt = sn.add_constant(x_multi)
x_multi_constt.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  teachers  poor_prop  \
# 0    0.006300       32.31     0.538     6.575  65.2      24.7       4.98
# 1    0.026944       37.07     0.469     6.421  78.9      22.2       9.14
# 2    0.026924       37.07     0.469     7.185  61.1      22.2       4.03
# 3    0.031857       32.18     0.458     6.998  45.8      21.3       2.94
# 4    0.066770       32.18     0.458     7.147  54.2      21.3       5.33
#
#    n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  airport_YES  \
# 0       5.480     11.19200        23  0.049347    4.0875            1
# 1       7.332     12.17280        42  0.046146    4.9675            0
# 2       7.394     30.79904        38  0.045764    4.9675            0
# 3       9.268     11.26720        45  0.047151    6.0650            1
# 4       8.824     11.28960        55  0.039474    6.0625            0
#
#    waterbody_Lake  waterbody_Lake and River  waterbody_River  bus_ter_YES
# ...

# %%
lm_multi = sn.OLS(y_multi , x_multi_constt).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.722
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     79.32
# Date:                Sun, 21 Nov 2021   Prob (F-statistic):          1.60e-124
# Time:                        09:58:06   Log-Likelihood:                -1515.7
# No. Observations:                 506   AIC:                             3065.
# Df Residuals:                     489   BIC:                             3137.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
lm3 = LinearRegression()

# %%
lm3.fit(x_multi,y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# -7.815355561156732 [ 1.94079686e-02 -4.03548783e-02 -2.08107998e+01  4.02124274e+00
#  -5.44258280e-03  1.01267721e+00 -5.78437027e-01  3.40675149e-01
#   1.39060368e-01  1.61989793e-02  5.82619593e+01 -1.21430517e+00
#   1.10581868e+00  2.62021907e-01 -6.99177103e-01 -2.70869535e-01
#   0.00000000e+00]

# %%
# TEST-TRAIN SPLIT
#1. VALIDATION SET APPROACH ( RANDOMLY DIVIDE )
#2. LEAVE ONE OUT CROSS VALIDATION ( N- TEST , (N-1)- TRAIN )
#3. K-FOLD VALIDATION

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x_multi,y_multi,test_size=0.2,random_state=0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (404, 17) (102, 17) (404,) (102,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(x_test)
y_train_a = lm_a.predict(x_train)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_test_a)
# Out:
# 0.5488133110060619

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.7578228447901874

# %%
# SHRINKAGE METHOD
#1. RIDGE REGRESSION
#2. LASSO REGRESSION

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.StandardScaler().fit(x_train)

# %%
x_train_s = scaler.transform(x_train)

# %%
x_test_s = scaler.transform(x_test)

# %%
from sklearn.linear_model import Ridge
lm_r = Ridge(alpha=0.5)# lambda
lm_r.fit(x_train_s,y_train)
# Out:
# Ridge(alpha=0.5)

# %%
lm_test_p = lm_r.predict(x_test_s)

# %%
r2_score(y_test,lm_test_p)
# Out:
# 0.5486484442009714

# %%
#ye to alag cheez ho gayi
from sklearn.model_selection import validation_curve

# %%
validation_curve?

# %%
param_range = np.logspace(-2,8,100)

# %%
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores,test_scores = validation_curve(Ridge(),x_train_s,y_train,"alpha",param_range,scoring='r2')
# Out:
# C:\Users\Lenovo\Documents\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass param_name=alpha, param_range=[1.00000000e-02 1.26185688e-02 1.59228279e-02 2.00923300e-02
#  2.53536449e-02 3.19926714e-02 4.03701726e-02 5.09413801e-02
#  6.42807312e-02 8.11130831e-02 1.02353102e-01 1.29154967e-01
#  1.62975083e-01 2.05651231e-01 2.59502421e-01 3.27454916e-01
#  4.13201240e-01 5.21400829e-01 6.57933225e-01 8.30217568e-01
#  1.04761575e+00 1.32194115e+00 1.66810054e+00 2.10490414e+00
#  2.65608778e+00 3.35160265e+00 4.22924287e+00 5.33669923e+00
#  6.73415066e+00 8.49753436e+00 1.07226722e+01 1.35304777e+01
#  1.70735265e+01 2.15443469e+01 2.71858824e+01 3.43046929e+01
#  4.32876128e+01 5.46227722e+01 6.89261210e+01 8.69749003e+01
#  1.09749877e+02 1.38488637e+02 1.74752840e+02 2.20513074e+02
#  2.78255940e+02 3.51119173e+02 4.43062146e+02 5.59081018e+02
#  7.05480231e+02 8.90215085e+02 1.12332403e+03 1.41747416e+03
# ...

# %%
print(train_scores)
# Out:
# [[7.51076730e-01 7.64318663e-01 7.54375585e-01 7.82425033e-01
#   7.47740493e-01]
#  [7.51076729e-01 7.64318662e-01 7.54375584e-01 7.82425033e-01
#   7.47740492e-01]
#  [7.51076727e-01 7.64318660e-01 7.54375582e-01 7.82425032e-01
#   7.47740490e-01]
#  [7.51076724e-01 7.64318657e-01 7.54375580e-01 7.82425030e-01
#   7.47740487e-01]
#  [7.51076719e-01 7.64318653e-01 7.54375576e-01 7.82425028e-01
#   7.47740483e-01]
#  [7.51076710e-01 7.64318645e-01 7.54375570e-01 7.82425024e-01
#   7.47740477e-01]
#  [7.51076697e-01 7.64318633e-01 7.54375560e-01 7.82425017e-01
#   7.47740466e-01]
#  [7.51076677e-01 7.64318614e-01 7.54375544e-01 7.82425007e-01
#   7.47740449e-01]
#  [7.51076644e-01 7.64318584e-01 7.54375519e-01 7.82424991e-01
#   7.47740422e-01]
#  [7.51076591e-01 7.64318536e-01 7.54375479e-01 7.82424965e-01
#   7.47740380e-01]
#  [7.51076508e-01 7.64318459e-01 7.54375416e-01 7.82424924e-01
#   7.47740312e-01]
#  [7.51076376e-01 7.64318338e-01 7.54375316e-01 7.82424858e-01
# ...

# %%
print(test_scores)
# Out:
# [[ 7.70279789e-01  7.08146721e-01  7.65527856e-01  6.62728068e-01
#    7.82177015e-01]
#  [ 7.70283560e-01  7.08148904e-01  7.65527662e-01  6.62726182e-01
#    7.82177024e-01]
#  [ 7.70288319e-01  7.08151657e-01  7.65527417e-01  6.62723801e-01
#    7.82177036e-01]
#  [ 7.70294321e-01  7.08155130e-01  7.65527107e-01  6.62720798e-01
#    7.82177050e-01]
#  [ 7.70301891e-01  7.08159509e-01  7.65526715e-01  6.62717009e-01
#    7.82177067e-01]
#  [ 7.70311439e-01  7.08165030e-01  7.65526220e-01  6.62712230e-01
#    7.82177087e-01]
#  [ 7.70323479e-01  7.08171989e-01  7.65525594e-01  6.62706200e-01
#    7.82177109e-01]
#  [ 7.70338658e-01  7.08180759e-01  7.65524800e-01  6.62698594e-01
#    7.82177132e-01]
#  [ 7.70357791e-01  7.08191806e-01  7.65523795e-01  6.62689002e-01
#    7.82177154e-01]
#  [ 7.70381901e-01  7.08205717e-01  7.65522520e-01  6.62676904e-01
#    7.82177171e-01]
#  [ 7.70412273e-01  7.08223222e-01  7.65520901e-01  6.62661650e-01
#    7.82177175e-01]
# ...

# %%
train_mean=np.mean(train_scores,axis=1)

# %%
test_mean = np.mean(test_scores,axis=1)

# %%
train_mean
# Out:
# array([7.59987301e-01, 7.59987300e-01, 7.59987298e-01, 7.59987296e-01,
#        7.59987292e-01, 7.59987285e-01, 7.59987275e-01, 7.59987258e-01,
#        7.59987232e-01, 7.59987190e-01, 7.59987124e-01, 7.59987019e-01,
#        7.59986852e-01, 7.59986587e-01, 7.59986167e-01, 7.59985503e-01,
#        7.59984454e-01, 7.59982799e-01, 7.59980198e-01, 7.59976119e-01,
#        7.59969748e-01, 7.59959845e-01, 7.59944536e-01, 7.59921037e-01,
#        7.59885256e-01, 7.59831298e-01, 7.59750830e-01, 7.59632322e-01,
#        7.59460177e-01, 7.59213727e-01, 7.58866051e-01, 7.58382424e-01,
#        7.57718072e-01, 7.56814795e-01, 7.55595993e-01, 7.53959817e-01,
#        7.51770529e-01, 7.48848642e-01, 7.44961051e-01, 7.39813213e-01,
#        7.33046605e-01, 7.24245646e-01, 7.12958315e-01, 6.98732392e-01,
#        6.81164310e-01, 6.59951312e-01, 6.34933512e-01, 6.06114685e-01,
#        5.73660005e-01, 5.37880870e-01, 4.99222738e-01, 4.58265718e-01,
# ...

# %%
sns.jointplot(x=np.log(param_range),y=test_mean)

# %%
max(test_mean)
# Out:
# 0.7389697251430292

# %%
param_range[33]
# Out:
# 21.544346900318846

# %%
lm_r_best=Ridge(alpha=param_range[33])

# %%
lm_r_best.fit(x_train_s,y_train)
# Out:
# Ridge(alpha=21.544346900318846)

# %%
r2_score(y_test,lm_r_best.predict(x_test_s))
# Out:
# 0.5407457129160114

# %%
r2_score(y_train,lm_r_best.predict(x_train_s))
# Out:
# 0.755571261241327
